# %%
k=3
x1=[['Raj',30],['Shreya',40],['Sushil',50],['Divya',70],['Sonali',90],
    ['Aishwariya',68],['Harshit',78],['Satyajeet',88],['Harshit',45],['Satyajeet',90]]

mean=[40,60,85]

dis=[]
a=[]
b=[]
c=[]
g1=[]
g2=[]
g3=[]
new_mean=[]


    


    
print(mean)    
#find dist
for i in range(len(x1)):
    
    a.append(( ((x1[i][1]-mean[0])**2)**0.5))
    b.append(( ((x1[i][1]-mean[1])**2)**0.5 ))
    c.append( ( ((x1[i][1]-mean[2])**2)**0.5 ))
        
print("*"*100)        

print(a)
print(b)
print(c)


#make group
for i in range(len(x1)):
    if(a[i]<b[i] and a[i]<c[i]):
        g1.append([x1[i][0],x1[i][1]])
    elif(b[i]<a[i] and b[i]<c[i]):
        g2.append([x1[i][0],x1[i][1]])
    else:
        g3.append([x1[i][0],x1[i][1]])
print("*"*100)
print('Group C',g1)
print('Group B',g2)
print('Group A',g3)
print("*"*100)

#update mean
def new_mean1(g1,g2,g3):
    new_mean.clear()
    sumofa=0
    for i in range(len(g1)):    
        sumofa+=g1[i][1]
        a1=(round(sumofa/len(g1)))
        
        sumofb=0
    for i in range(len(g2)):    
        sumofb+=g2[i][1]
        a2=(round(sumofb/len(g2))) 
        sumofc=0
    for i in range(len(g3)):    
        sumofc+=g3[i][1]
        a3=(round(sumofc/len(g3)))
    new_mean.append(a1)
    new_mean.append(a2)
    new_mean.append(a3)
    
    
#update distance
def update_distance(a,b,c,x1,new_mean):
    a.clear()
    b.clear()
    c.clear()
    for i in range(len(x1)):

        a.append(((x1[i][1]-new_mean[0])**2)**0.5)
        b.append(((x1[i][1]-new_mean[1])**2)**0.5 )
        c.append(((x1[i][1]-new_mean[2])**2)**0.5 )

    print("*"*100)        
    
    print(a)
    print(b)
    print(c)

    
#make group
def updategroup(a,b,c,x1,g1,g2,g3):
    g1.clear()
    g2.clear()
    g3.clear()
    for i in range(len(x1)):
        if(a[i]<b[i] and a[i]<c[i]):
            g1.append([x1[i][0],x1[i][1]])
        elif(b[i]<a[i] and b[i]<c[i]):
            g2.append([x1[i][0],x1[i][1]])
        else:
            g3.append([x1[i][0],x1[i][1]])

    print("*"*100)
    print('Group C',g1)
    print('Group B',g2)
    print('Group A',g3)

i=0
while(i<3):
    
    new_mean1(g1,g2,g3)
    print("*"*100)
    print(new_mean)
    update_distance(a,b,c,x1,new_mean)
    updategroup(a,b,c,x1,g1,g2,g3)
    i+=1
# Out:
# [40, 60, 85]
# ****************************************************************************************************
# [10.0, 0.0, 10.0, 30.0, 50.0, 28.0, 38.0, 48.0, 5.0, 50.0]
# [30.0, 20.0, 10.0, 10.0, 30.0, 8.0, 18.0, 28.0, 15.0, 30.0]
# [55.0, 45.0, 35.0, 15.0, 5.0, 17.0, 7.0, 3.0, 40.0, 5.0]
# ****************************************************************************************************
# Group C [['Raj', 30], ['Shreya', 40], ['Harshit', 45]]
# Group B [['Divya', 70], ['Aishwariya', 68]]
# Group A [['Sushil', 50], ['Sonali', 90], ['Harshit', 78], ['Satyajeet', 88], ['Satyajeet', 90]]
# ****************************************************************************************************
# ****************************************************************************************************
# [38, 69, 79]
# ****************************************************************************************************
# [8.0, 2.0, 12.0, 32.0, 52.0, 30.0, 40.0, 50.0, 7.0, 52.0]
# ...
